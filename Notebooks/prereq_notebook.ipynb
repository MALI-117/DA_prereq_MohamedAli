# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# I am an Engineer working at GEA as a Software Project Manager. I've done intro to python on LinkedIN several times - I am excited to take it even further and do projects through the Data Analysis Pathway.
